# %% [markdown]
# # Working with the DB

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
df_url = "./data/stages_data/full_stage_df.csv"


df = pd.read_csv(df_url)


df = (
    df
    .assign(
        stage = lambda df_: df_["stage"].str.split("_").str[1]
    )
    # round to 3dp
    .round(3)
)

# %%
df.head()
# Out:
#     index  Unnamed: 0.1  Unnamed: 0  \
# 53     59            59          57
# 63     69            69         633
# 72     79            79         253
# 1      31            31         123
# 59     65            65         180
#
#                                           review_text  \
# 53  "The Hotel Allegro Chicago was an excellent ch...
# 63  We needed an extra night in Chicago after a gr...
# 72  "The Millennium Knickerbocker Hotel Chicago is...
# 1   "I had a wonderful stay at the Fairmont Chicag...
# 59  "I had an amazing stay at the Hyatt Regency Ch...
#
#     proportion_of_emotional_content_in_review  \
# 53                                      11.86
# 63                                       7.46
# 72                                      13.33
# 1                                       12.28
# 59                                      13.79
#
#     proportion_of_adjectives_in_review  readability_of_review  \
# 53                               11.86                 52.245
# ...

# %%
features = [
    "review_text",
    "proportion_of_emotional_content_in_review",
    "proportion_of_adjectives_in_review",
    "readability_of_review",
    "analytic_writing_style",
    "ebm_prediction",
    "mis_classified",
    "model_pred_confidence",
    "stage"   
]


def db_insert(df, db_url, table_name):
    """
    Inserts data from a Pandas DataFrame into the PostgreSQL 'Reviews' table.
    
    Parameters:
    - df: Pandas DataFrame with the specified columns.
    - db_url: Database connection string, e.g., 'postgresql://user:password@localhost:5432/mydatabase'
    - table_name: Name of the table in the DB
    
    Note: Since 'review_id' is SERIAL (auto-increment), it's not included in the DF.
    This function appends new rows to the table.
    """
    # Create SQLAlchemy engine
    engine = create_engine(db_url)
    try:
        df.to_sql(table_name, engine, if_exists='append', index=False)
    except error as e:
        print(e)
    else:
        print(f"Successfully inserted {len(df)} rows into the {table_name} table.")



pg_db_url = "postgresql://xai_user:interactive_xai@localhost:5432/interactive_xai_db"
reviews_df = df[features]


db_insert(df=reviews_df, db_url=pg_db_url, table_name="reviews")
# Out:
# Successfully inserted 28 rows into the 'Reviews' table.

# %%
# Confirm the insertion into DB
query = "SELECT * FROM reviews" 
pg_db_url = "postgresql://xai_user:interactive_xai@localhost:5432/interactive_xai_db"

pg_sql_df = pd.read_sql(query, pg_db_url)

pg_sql_df
# Out:
#     review_id                                        review_text  \
# 0           1  "The Hotel Allegro Chicago was an excellent ch...
# 1           2  We needed an extra night in Chicago after a gr...
# 2           3  "The Millennium Knickerbocker Hotel Chicago is...
# 3           4  "I had a wonderful stay at the Fairmont Chicag...
# 4           5  "I had an amazing stay at the Hyatt Regency Ch...
# 5           6  "I recently stayed at the InterContinental Chi...
# 6           7  This was a great hotel right in the heart of t...
# 7           8  We just returned from a girls shopping /sight-...
# 8           9  I loved this hotel - reasonable for downtown C...
# 9          10  My boyfriend and I were amazed by the breathta...
# 10         11  Stayed here on business a few nights and reall...
# 11         12  "I recently stayed at the InterContinental Chi...
# 12         13  "I recently stayed at Ambassador East Hotel Ch...
# ...

# %%
(
    pg_sql_df
    .drop(columns=["review_id", "mis_classified", "model_pred_confidence","stage"])
).to_csv("./data/data_for_nl_exp_gen.csv")

# %%
[(1, 'malomo@uncg.edu', 'NVezy_E76.3TsT8')][0][0]
# Out:
# 1

# %%
int(pg_sql_df["review_id"][0])
# Out:
# 1

# %%
# Confirm the insertion into DB
query = "SELECT * FROM responses WHERE user_id = 13" 
pg_db_url = "postgresql://xai_user:interactive_xai@localhost:5432/interactive_xai_db"

pg_sql_df = pd.read_sql(query, pg_db_url)

pg_sql_df
# Out:
#     response_id  user_id  review_id initial_decision final_decision  \
# 0           125       13          4             None        Genuine
# 1           122       13          1             None      Deceptive
# 2           123       13          2             None        Genuine
# 3           126       13          5             None      Deceptive
# 4           124       13          3             None      Deceptive
# 5           127       13          6             None      Deceptive
# 6           128       13          7             None        Genuine
# 7           129       13          8             None        Genuine
# 8           130       13          9        Deceptive      Deceptive
# 9           131       13         10          Genuine        Genuine
# 10          132       13         11          Genuine      Deceptive
# 11          133       13         12          Genuine      Deceptive
# 12          134       13         13          Genuine      Deceptive
# ...

# %%
pg_sql_df
# Out:
#     review_id                                        review_text  \
# 0           1  "The Hotel Allegro Chicago was an excellent ch...
# 1           2  We needed an extra night in Chicago after a gr...
# 2           3  "The Millennium Knickerbocker Hotel Chicago is...
# 3           4  "I had a wonderful stay at the Fairmont Chicag...
# 4           5  "I had an amazing stay at the Hyatt Regency Ch...
# 5           6  "I recently stayed at the InterContinental Chi...
# 6           7  This was a great hotel right in the heart of t...
# 7           8  We just returned from a girls shopping /sight-...
# 8           9  I loved this hotel - reasonable for downtown C...
# 9          10  My boyfriend and I were amazed by the breathta...
# 10         11  Stayed here on business a few nights and reall...
# 11         12  "I recently stayed at the InterContinental Chi...
# 12         13  "I recently stayed at Ambassador East Hotel Ch...
# ...
